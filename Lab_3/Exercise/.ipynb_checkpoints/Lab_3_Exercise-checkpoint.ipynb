# %%
### aa

# %%
# Importing common libraries 
import pandas as pd
import numpy as np
from sklearn import metrics
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("House_data.csv")

# %%
data.head(5)
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
#check mising data
data.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
data.shape
# Out:
# (21613, 21)

# %%
# Let's see how Sales are related with other variables using scatter plot.
# Using pairplot we'll visualize the data for correlation
sns.pairplot(data, x_vars=['sqft_living','bathrooms', 'bedrooms','sqft_basement' ,'sqft_above'], 
             y_vars='price', height=3, aspect=1, kind='scatter')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(14,10)) #code untuk besar kan heatmap

# Visualizing the data using heatmap
sns.heatmap(data.corr(numeric_only = True ), annot = True)
plt.show()

# %%
#Try prediction with TV as feature
#use reshape(-1,1) for a single feature; i.e. single column
X=data[['sqft_living','bathrooms', 'bedrooms','sqft_basement' ,'sqft_above']]

y=data.price.values.reshape(-1,1)

# %%
X
# Out:
#        sqft_living  bathrooms  bedrooms  sqft_basement  sqft_above
# 0             1180       1.00         3              0        1180
# 1             2570       2.25         3            400        2170
# 2              770       1.00         2              0         770
# 3             1960       3.00         4            910        1050
# 4             1680       2.00         3              0        1680
# ...            ...        ...       ...            ...         ...
# 21608         1530       2.50         3              0        1530
# 21609         2310       2.50         4              0        2310
# 21610         1020       0.75         2              0        1020
# 21611         1600       2.50         3              0        1600
# 21612         1020       0.75         2              0        1020
#
# [21613 rows x 5 columns]

# %%
y
# Out:
# array([[221900.],
#        [538000.],
#        [180000.],
#        ...,
#        [402101.],
#        [400000.],
#        [325000.]])
